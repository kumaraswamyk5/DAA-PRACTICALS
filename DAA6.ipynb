# %%
# Matrix Chain Multiplication using Dynamic Programming

n = int(input("Enter number of matrices: "))

print("Enter dimensions of matrices:")

p = []

for i in range(n + 1):
    p.append(int(input(f"Enter dimension {i + 1}: ")))

# Create DP table
dp = [[0 for j in range(n)] for i in range(n)]

# Calculate minimum multiplication cost
for length in range(2, n + 1):
    for i in range(n - length + 1):
        j = i + length - 1
        dp[i][j] = float('inf')

        for k in range(i, j):
            cost = (dp[i][k] +
                    dp[k + 1][j] +
                    p[i] * p[k + 1] * p[j + 1])

            if cost < dp[i][j]:
                dp[i][j] = cost

print("\nMinimum number of multiplications:", dp[0][n - 1])
# Out:
# Enter number of matrices:  3
# Enter dimensions of matrices:
# Enter dimension 1:  10
# Enter dimension 2:  20
# Enter dimension 3:  30
# Enter dimension 4:  40
# Minimum number of multiplications: 18000
